# %% [markdown]
# # 2

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import os
import sys

base_path = os.path.normpath(os.path.join(os.getcwd(), ".."))
if base_path not in sys.path:
    sys.path.append(base_path)

# %%
import manim as mn
from manim import *

mn.config.media_width = "75%"
mn.config.verbosity = "WARNING"
mn.config.media_embed = True

print(mn.__version__)
# Out:
# 0.19.0

# %%
from lfd import load_dset
from manimations.main import (
    demo_to_points,
    find_scale_and_mean,
    normalize_points,
    hsv_to_manim_color,
)

# %%
param = "-v WARNING -ql --disable_caching"
paramSMALL = "-v WARNING -r 400,200 --disable_caching"

# %%
dset = load_dset("s")

# %%
# %%manim $param DemonstrationScene3D
#
#
# class DemonstrationScene3D(mn.ThreeDScene):
#     def setup(self):
#         self.camera.background_color = mn.BLACK
#
#     def construct(self):
#         # Set an isometric camera view
#         self.set_camera_orientation(phi=60 * mn.DEGREES, theta=-45 * mn.DEGREES)
#
#         scale, mean = find_scale_and_mean(dset[-1])
#
#         # Loop and draw each trajectory
#         num_traj = len(dset)
#         for i, traj in enumerate(dset[:num_traj]):
#             arr = demo_to_points(traj, include_z=True)
#             norm_points = normalize_points(arr, scale, mean)
#
#             color = hsv_to_manim_color(i / len(dset))
#             path = mn.VMobject()
#             path.set_points_as_corners(norm_points)
#             path.set_stroke(color=color, width=3)
#
#             self.begin_ambient_camera_rotation(rate=0.015)
#             self.play(mn.Create(path), run_time=2)
#             self.stop_ambient_camera_rotation()
# Out:
# Manim Community v0.19.0
# <video controls autoplay loop style="max-width: 75%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
